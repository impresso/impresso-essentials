# %% [markdown]
# # Debug notebook for the Script adding a provider layer to S3

# %% [markdown]
# ### Imports

# %%
import os
import boto3
from impresso_essentials.io.s3 import (
    IMPRESSO_STORAGEOPT,
    get_s3_resource,
    get_s3_client
)
from impresso_essentials.utils import get_provider_for_alias, ALL_MEDIA, PARTNER_TO_MEDIA
from urllib.parse import urlparse
import signal
from contextlib import contextmanager

# %% [markdown]
# ### Implement the function adding the provider given the S3 path

# %%
@contextmanager
def disable_interrupts():
    """Context manager to temporarily disable keyboard interrupts."""
    original_handler = signal.getsignal(signal.SIGINT)
    signal.signal(signal.SIGINT, signal.SIG_IGN)
    try:
        yield
    finally:
        signal.signal(signal.SIGINT, original_handler)

# %%
t_s = 'fd'

if t_s:
    print('yes')
else:
    print('no')
# Out:
# yes

# %%
def get_alias_from_path(source_path, og_partition):
    if not og_partition.endswith('/') and og_partition!= '':
        og_partition = og_partition + "/"

    split = source_path.replace(og_partition, "").split('/') if og_partition else source_path.split('/')

    # make sure to know if the partner is already in this path or not
    if split[0] in ALL_MEDIA:
        #print(f"returnning split[0], None: {split[0], None}")
        return split[0], None
    elif split[0] in PARTNER_TO_MEDIA and split[1] in PARTNER_TO_MEDIA[split[0]]:
        # also return the provider if it's there
        #print(f"returnning split[1], split[0]: {split[1], split[0]}")
        return split[1], split[0]
    else:
        msg = f"The source path {source_path} does not contain the media alias at an expected place."
        raise AttributeError(msg)

# %%
s3_path = "s3://22-rebuilt-final/actionfem/actionfem-1928.jsonl.bz2"
s3_path = "s3://42-processed-data-final/langident/langident_v1-4-4/CL/CL-1883.jsonl.bz2"
partition = "s3://42-processed-data-final/langident/langident_v1-4-4"

get_alias_from_path(s3_path, partition)
# Out:
# 'CL'

# %%
def construct_dest_key(src_key, provider, og_partition, current_alias=None, found_prov=None):
    if found_prov:
        print(f"construct_dest_key - found_provider is not None ({found_prov}), skipping, and returning key as-is: {src_key}")
        return src_key
    #print(f"og_partition : {og_partition}, current_alias={current_alias}")
    if og_partition != '':
        return src_key.replace(og_partition, os.path.join(og_partition, provider))
    
    # if there is no specific partition, the provider becomes the first element of the key
    return os.path.join(provider, src_key)

# %%
"""def construct_dest_key(source_key, curr_alias, provider, og_partition):

    #stripped_partition = '/'.join(og_partition.split('/')[3:])

    media_alias, found_prov = get_alias_from_path(source_key, og_partition)
    print(f" media_alias, found_prov: {media_alias, found_prov}")
    if found_prov != provider:
        print(f"PROBLEM: the provider is already in the path found_prov={found_prov}, and different from provider: {provider}")

    if media_alias != curr_alias or provider is None:
        print(f"PROBLEM: curr_alias={curr_alias}, media_alias: {media_alias}")
        found_prov = get_provider_for_alias(media_alias)

    full_dest_path = reconstruct_dest(source_key, og_partition, found_prov)
    
    return full_dest_path"""
# Out:
# 'def construct_dest_key(source_key, curr_alias, provider, og_partition):\n\n    #stripped_partition = \'/\'.join(og_partition.split(\'/\')[3:])\n\n    media_alias, found_prov = get_alias_from_path(source_key, og_partition)\n    print(f" media_alias, found_prov: {media_alias, found_prov}")\n    if found_prov != provider:\n        print(f"PROBLEM: the provider is already in the path found_prov={found_prov}, and different from provider: {provider}")\n\n    if media_alias != curr_alias or provider is None:\n        print(f"PROBLEM: curr_alias={curr_alias}, media_alias: {media_alias}")\n        found_prov = get_provider_for_alias(media_alias)\n\n    full_dest_path = reconstruct_dest(source_key, og_partition, found_prov)\n    \n    return full_dest_path'

# %%
s3_path = "s3://22-rebuilt-final/actionfem/actionfem-1928.jsonl.bz2"
#s3_path = "s3://42-processed-data-final/langident/langident_v1-4-4/CL/CL-1883.jsonl.bz2"

og_partition = "s3://22-rebuilt-final"
#og_partition = "s3://42-processed-data-final/langident/langident_v1-4-4"

stripped_partition = '/'.join(og_partition.split('/')[3:])

print(stripped_partition)
parsed = urlparse(s3_path)
src_bucket = parsed.netloc
src_key = parsed.path.lstrip("/")
dest_bucket = "122-rebuilt-staging"
provider = 'BNL'
alias = "actionfem"


construct_dest_key(src_key, provider, alias, og_partition)
# Out:
# 'actionfem/actionfem-1928.jsonl.bz2'

# %%
s3_path
# Out:
# 's3://42-processed-data-final/langident/langident_v1-4-4/CL/CL-1883.jsonl.bz2'

# %%
s3_c = get_s3_client()

parsed = urlparse(s3_path)
bucket = parsed.netloc
key = parsed.path.lstrip("/")


print(bucket, key, s3_path)
s3_c.head_object(Bucket=bucket, Key=key)
# Out:
# 22-rebuilt-final actionfem/actionfem-1928.jsonl.bz2 s3://22-rebuilt-final/actionfem/actionfem-1928.jsonl.bz2
# {'ResponseMetadata': {'RequestId': 'tx00000a293b46b9407dd86-006863e9f1-2487f759b-default',
#   'HostId': '',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'server': 'nginx',
#    'date': 'Tue, 01 Jul 2025 14:00:18 GMT',
#    'content-type': 'binary/octet-stream',
#    'content-length': '768962',
#    'connection': 'keep-alive',
#    'accept-ranges': 'bytes',
#    'last-modified': 'Thu, 15 May 2025 22:34:15 GMT',
#    'x-rgw-object-type': 'Normal',
#    'etag': '"27912107d7250c8ffc3e2ede5c6caab6"',
#    'x-amz-meta-impresso-last-ts': '2024-03-04T18:34:32Z',
#    'x-amz-meta-mtime': '1709577450.524',
#    'x-amz-request-id': 'tx00000a293b46b9407dd86-006863e9f1-2487f759b-default',
#    'strict-transport-security': 'max-age=31536000; includeSubdomains'},
#   'RetryAttempts': 0},
#  'AcceptRanges': 'bytes',
#  'LastModified': datetime.datetime(2025, 5, 15, 22, 34, 15, tzinfo=tzutc()),
#  'ContentLength': 768962,
#  'ETag': '"27912107d7250c8ffc3e2ede5c6caab6"',
#  'ContentType': 'binary/octet-stream',
#  'Metadata': {'impresso-last-ts': '2024-03-04T18:34:32Z',
#   'mtime': '1709577450.524'}}

# %%
def add_provider_to_s3_partition(src_bucket, dest_bucket, exact_partition, perform_copy=False, metadata_directive="COPY"):

    s3 = get_s3_client()

    paginator = s3.get_paginator("list_objects_v2")
    page_iterator = paginator.paginate(Bucket=src_bucket, Prefix=exact_partition)

    current_alias = None
    provider = None
    for page in page_iterator:
        for obj in page.get("Contents", []):
            key = obj["Key"]
            #print(f"        key: {key}, key.split('/')[-2]: {key.split('/')[-2]}")
            if key[:-1]==exact_partition:
                print(f"partition: {key}")
            elif not key.endswith(".jsonl.bz2") and key.endswith("/"):
                current_alias = key.split('/')[-2]
                provider = get_provider_for_alias(current_alias)
                print(f"Now processing alias {current_alias} - provider = {provider}")
            elif key.endswith(".jsonl.bz2"):

                # check if we have now changed Alias or provider
                new_alias, found_prov = get_alias_from_path(key, exact_partition)

                if current_alias!=new_alias:
                    current_alias=new_alias
                    provider = get_provider_for_alias(current_alias)
                    print(f"Found new alias in key - Now processing alias {current_alias} - provider = {provider}")

                #print(f"    file key: {key} - current_alias: {current_alias}, provider={provider}, exact_partition: {exact_partition}.")
                dest_key = construct_dest_key(key, provider, exact_partition, current_alias, found_prov)
                if perform_copy:
                    if dest_key!=key:

                        try: 
                            existing_dest = s3.head_object(Bucket=dest_key, Key=dest_key)
                            print(f"    The destination key {dest_key} already exists in bucket {dest_bucket}, skipping - {existing_dest}")
                        except Exception as e:
                            # the destination does not exist yet, perform the copy
                            #existing_metadata = s3_c.head_object(Bucket=src_bucket, Key="SOC_VS/SOC_VS-1944.jsonl.bz2").get("Metadata", {})
                            if False:
                                print(f"    File key {key} will be copied to here: {dest_key} in bucket {dest_bucket}")
                                with disable_interrupts():
                                    s3.copy_object(
                                        Bucket=dest_bucket,
                                        Key=dest_key,
                                        CopySource={"Bucket": src_bucket, "Key": key},
                                        MetadataDirective=metadata_directive,
                                    )
                    else:
                        print(f"    will NOT copy {key} to {dest_key} - same key or no copy")
            else:
                print(f"    -> another file: {key}")

# %% [markdown]
# ## TODO add function to delete after, check that the alias is in aliases but also that the provider is in providers (eg. NZZ!!)

# %%
#og_partition = "s3://42-processed-data-final/langident/langident_v1-4-4"
og_partition = "s3://120-rebuilt-sandbox/"

parsed = urlparse(og_partition)
src_bucket = parsed.netloc
exact_partition = parsed.path.lstrip("/")

dest_bucket = '120-rebuilt-sandbox'

src_bucket, exact_partition
# Out:
# ('120-rebuilt-sandbox', '')

# %%
add_provider_to_s3_partition(src_bucket, dest_bucket, exact_partition, perform_copy=True)
# Out:
# Found new alias in key - Now processing alias ACI - provider = BCUL
#     File key ACI/ACI-1832.jsonl.bz2 will be copied to here: BCUL/ACI/ACI-1832.jsonl.bz2 in bucket 120-rebuilt-sandbox
# Found new alias in key - Now processing alias AV - provider = BCUL
#     File key AV/AV-1880.jsonl.bz2 will be copied to here: BCUL/AV/AV-1880.jsonl.bz2 in bucket 120-rebuilt-sandbox
#     File key AV/AV-1881.jsonl.bz2 will be copied to here: BCUL/AV/AV-1881.jsonl.bz2 in bucket 120-rebuilt-sandbox
#     File key AV/AV-1886.jsonl.bz2 will be copied to here: BCUL/AV/AV-1886.jsonl.bz2 in bucket 120-rebuilt-sandbox
# Found new alias in key - Now processing alias ACI - provider = BCUL
# construct_dest_key - found_provider is not None (BCUL), skipping, and returning key as-is: BCUL/ACI/ACI-1832.jsonl.bz2
#     will NOT copy BCUL/ACI/ACI-1832.jsonl.bz2 to BCUL/ACI/ACI-1832.jsonl.bz2 - same key or no copy
# Found new alias in key - Now processing alias AV - provider = BCUL
# construct_dest_key - found_provider is not None (BCUL), skipping, and returning key as-is: BCUL/AV/AV-1880.jsonl.bz2
#     will NOT copy BCUL/AV/AV-1880.jsonl.bz2 to BCUL/AV/AV-1880.jsonl.bz2 - same key or no copy
# construct_dest_key - found_provider is not None (BCUL), skipping, and returning key as-is: BCUL/AV/AV-1881.jsonl.bz2
#     will NOT copy BCUL/AV/AV-1881.jsonl.bz2 to BCUL/AV/AV-1881.jsonl.bz2 - same key or no copy
# construct_dest_key - found_provider is not None (BCUL), skipping, and returning key as-is: BCUL/AV/AV-1886.jsonl.bz2
#     will NOT copy BCUL/AV/AV-1886.jsonl.bz2 to BCUL/AV/AV-1886.jsonl.bz2 - same key or no copy
# Found new alias in key - Now processing alias Bombe - provider = BCUL
# construct_dest_key - found_provider is not None (BCUL), skipping, and returning key as-is: BCUL/Bombe/Bombe-1889.jsonl.bz2
#     will NOT copy BCUL/Bombe/Bombe-1889.jsonl.bz2 to BCUL/Bombe/Bombe-1889.jsonl.bz2 - same key or no copy
# Found new alias in key - Now processing al
jsonl.bz2 in bucket 120-rebuilt-sandbox
#     File key waechtersauer/waechtersauer-1869.jsonl.bz2 will be copied to here: BNL/waechtersauer/waechtersauer-1869.jsonl.bz2 in bucket 120-rebuilt-sandbox
# Found new alias in key - Now processing alias waeschfra - provider = BNL
#     File key waeschfra/waeschfra-1868.jsonl.bz2 will be copied to here: BNL/waeschfra/waeschfra-1868.jsonl.bz2 in bucket 120-rebuilt-sandbox
#     File key waeschfra/waeschfra-1869.jsonl.bz2 will be copied to here: BNL/waeschfra/waeschfra-1869.jsonl.bz2 in bucket 120-rebuilt-sandbox
#     File key waeschfra/waeschfra-1870.jsonl.bz2 will be copied to here: BNL/waeschfra/waeschfra-1870.jsonl.bz2 in bucket 120-rebuilt-sandbox
#     File key waeschfra/waeschfra-1871.jsonl.bz2 will be copied to here: BNL/waeschfra/waeschfra-1871.jsonl.bz2 in bucket 120-rebuilt-sandbox
#     File key waeschfra/waeschfra-1872.jsonl.bz2 will be copied to here: BNL/waeschfra/waeschfra-1872.jsonl.bz2 in bucket 120-rebuilt-sandbox
#     File key waeschfra/waeschfra-1873.jsonl.bz2 will be copied to here: BNL/waeschfra/waeschfra-1873.jsonl.bz2 in bucket 120-rebuilt-sandbox
#     File key waeschfra/waeschfra-1874.jsonl.bz2 will be copied to here: BNL/waeschfra/waeschfra-1874.jsonl.bz2 in bucket 120-rebuilt-sandbox
#     File key waeschfra/waeschfra-1875.jsonl.bz2 will be copied to here: BNL/waeschfra/waeschfra-1875.jsonl.bz2 in bucket 120-rebuilt-sandbox
#     File key waeschfra/waeschfra-1876.jsonl.bz2 will be copied to here: BNL/waeschfra/waeschfra-1876.jsonl.bz2 in bucket 120-rebuilt-sandbox
#     File key waeschfra/waeschfra-1877.jsonl.bz2 will be copied to here: BNL/waeschfra/waeschfra-1877.jsonl.bz2 in bucket 120-rebuilt-sandbox
#     File key waeschfra/waeschfra-1878.jsonl.bz2 will be copied to here: BNL/waeschfra/waeschfra-1878.jsonl.bz2 in bucket 120-rebuilt-sandbox
#     File key waeschfra/waeschfra-1879.jsonl.bz2 will be copied to here: BNL/waeschfra/waeschfra-1879.jsonl.bz2 in bucket 120-rebuilt-sandbox
#     File key waeschfra/waeschfra-1880.jsonl.bz2 will be copied to here: BNL/waeschfra/waeschfra-1880.jsonl.bz2 in bucket 120-rebuilt-sandbox
#     File key waeschfra/waeschfra-1881.jsonl.bz2 will be copied to here: BNL/waeschfra/waeschfra-1881.jsonl.bz2 in bucket 120-rebuilt-sandbox
#     File key waeschfra/waeschfra-1882.jsonl.bz2 will be copied to here: BNL/waeschfra/waeschfra-1882.jsonl.bz2 in bucket 120-rebuilt-sandbox
#     File key waeschfra/waeschfra-1883.jsonl.bz2 will be copied to here: BNL/waeschfra/waeschfra-1883.jsonl.bz2 in bucket 120-rebuilt-sandbox
#     File key waeschfra/waeschfra-1884.jsonl.bz2 will be copied to here: BNL/waeschfra/waeschfra-1884.jsonl.bz2 in bucket 120-rebuilt-sandbox

# %%
add_provider_to_s3_partition(src_bucket, dest_bucket, exact_partition, perform_copy=True)
# Out:
# Found new alias in key - Now processing alias ACI - provider = BCUL
# Found new alias in key - Now processing alias AV - provider = BCUL
# Found new alias in key - Now processing alias ACI - provider = BCUL
# construct_dest_key - found_provider is not None (BCUL), skipping, and returning key as-is: BCUL/ACI/ACI-1832.jsonl.bz2
#     will NOT copy BCUL/ACI/ACI-1832.jsonl.bz2 to BCUL/ACI/ACI-1832.jsonl.bz2 - same key or no copy
# Found new alias in key - Now processing alias AV - provider = BCUL
# construct_dest_key - found_provider is not None (BCUL), skipping, and returning key as-is: BCUL/AV/AV-1880.jsonl.bz2
#     will NOT copy BCUL/AV/AV-1880.jsonl.bz2 to BCUL/AV/AV-1880.jsonl.bz2 - same key or no copy
# construct_dest_key - found_provider is not None (BCUL), skipping, and returning key as-is: BCUL/AV/AV-1881.jsonl.bz2
#     will NOT copy BCUL/AV/AV-1881.jsonl.bz2 to BCUL/AV/AV-1881.jsonl.bz2 - same key or no copy
# construct_dest_key - found_provider is not None (BCUL), skipping, and returning key as-is: BCUL/AV/AV-1886.jsonl.bz2
#     will NOT copy BCUL/AV/AV-1886.jsonl.bz2 to BCUL/AV/AV-1886.jsonl.bz2 - same key or no copy
# Found new alias in key - Now processing alias Bombe - provider = BCUL
# construct_dest_key - found_provider is not None (BCUL), skipping, and returning key as-is: BCUL/Bombe/Bombe-1889.jsonl.bz2
#     will NOT copy BCUL/Bombe/Bombe-1889.jsonl.bz2 to BCUL/Bombe/Bombe-1889.jsonl.bz2 - same key or no copy
# Found new alias in key - Now processing alias CL - provider = BCUL
# construct_dest_key - found_provider is not None (BCUL), skipping, and returning key as-is: BCUL/CL/CL-1882.jsonl.bz2
#     will NOT copy BCUL/CL/CL-1882.jsonl.bz2 to BCUL/CL/CL-1882.jsonl.bz2 - same key or no copy
# construct_dest_key - found_provider is not None (BCUL), skipping, and returning key as-is: BCUL/CL/CL-1883.jsonl.bz2
#     will NOT copy BCUL/CL/CL-1883.jsonl.bz2 to BCUL/CL/CL-1883.jsonl.bz2 - same key or no copy
# construct_dest_key - found_provider is not None (BCUL), skipping, and returning key as-is: BCUL/CL/CL-1884.jsonl.bz2
#     will NOT copy BCUL/CL/CL-1884.jsonl.bz2 to BCUL/CL/CL-1884.jsonl.bz2 - same key or no copy
# construct_dest_key - found_provider is not None (BCUL), skipping, and returning key as-is: BCUL/CL/CL-1885.jsonl.bz2
#     will NOT copy BCUL/CL/CL-1885.jsonl.bz2 to BCUL/CL/CL-1885.jsonl.bz2 - same key or no copy
# construct_dest_key - found_provider is not None (BCUL), skipping, and returning key as-is: BCUL/CL/CL-1886.jsonl.bz2
#     will NOT copy BCUL/CL/CL-1886.jsonl.bz2 to BCUL/CL/CL-1886.jsonl.bz2 - same key or no copy
# Found new alias in key - Now processing alias Cancoire - provider = BCUL
# construct_dest_key - found_provider is not None (BCUL), skipping, and returning key as-is: BCUL/Cancoire/Cancoire-1898.jsonl.bz2
#     will NOT copy BCUL/Cancoire/Cancoire-1898.jsonl.bz2 to BCUL/Cancoire/Cancoire-1898.jsonl.bz2 - same key or no copy
# Found new alias in key - Now processing alias Castigat - provider = BCUL
# construct_dest_key - found_provider is not None (BCUL), skipping, and returning key as-is: BCUL/Castigat/Castigat-1879.jsonl.bz2
#     will NOT copy BCUL/Castigat/Castigat-1879.jsonl.bz2 to BCUL/Castigat/Castigat-1879.jsonl.bz2 - same key or no copy
# construct_dest_key - found_provider is not None (BCUL), skipping, and returning key as-is: BCUL/Castigat/Castigat-1880.jsonl.bz2
#     will NOT copy BCUL/Castigat/Castigat-1880.jsonl.bz2 to BCUL/Castigat/Castigat-1880.jsonl.bz2 - same key or no copy
# Found new alias in key - Now processing alias Charivari - provider = BCUL
# construct_dest_key - found_provider is not None (BCUL), skipping, and returning key as-is: BCUL/Charivari/Charivari-1839.jsonl.bz2
#     will NOT copy BCUL/Charivari/Charivari-1839.jsonl.bz2 to BCUL/Charivari/Charivari-1839.jsonl.bz2 - same key or no copy
# construct_dest_key - found_provider is not None (BCUL), skipping, and returning key as-is: BCUL/Charivari/Charivari-1840.jsonl.bz2
#     will NOT copy BCUL/Charivari/Charivari-1840.jsonl.bz2 to BCUL/Charivari/Charivari-1840.jsonl.bz2 - same key or no copy
# construct_dest_key - found_provider is not None (BCUL), skipping, and returning key as-is: BCUL/Charivari/Charivari-1841.jsonl.bz2
#     will NOT copy BCUL/Charivari/Charivari-1841.jsonl.bz2 to BCUL/Charivari/Charivari-1841.jsonl.bz2 - same key or no copy
# Found new alias in key - Now processing alias CharivariCH - provider = BCUL
# construct_dest_key - found_provider is not None (BCUL), skipping, and returning key as-is: BCUL/CharivariCH/CharivariCH-1875.jsonl.bz2
#     will NOT copy BCUL/CharivariCH/CharivariCH-1875.jsonl.bz2 to BCUL/CharivariCH/CharivariCH-1875.jsonl.bz2 - same key or no copy
# construct_dest_key - found_provider is not None (BCUL), skipping, and returning key as-is: BCUL/CharivariCH/CharivariCH-1876.jsonl.bz2
#     will NOT copy BCUL/CharivariCH/CharivariCH-1876.jsonl.bz2 to BCUL/CharivariCH/CharivariCH-1876.jsonl.bz2 - same key or no copy
# construct_dest_key - found_provider is not None (BCUL), skipping, and returning key as-is: BCUL/CharivariCH/CharivariCH-1877.jsonl.bz2
#     will NOT copy BCUL/CharivariCH/CharivariCH-1877.jsonl.bz2 to BCUL/CharivariCH/CharivariCH-1877.jsonl.bz2 - same key or no copy
# Found new alias in key - Now processing alias
jsonl.bz2
#     will NOT copy SWISSINFO/SOC_SO/SOC_SO-1941.jsonl.bz2 to SWISSINFO/SOC_SO/SOC_SO-1941.jsonl.bz2 - same key or no copy
# construct_dest_key - found_provider is not None (SWISSINFO), skipping, and returning key as-is: SWISSINFO/SOC_SO/SOC_SO-1942.jsonl.bz2
#     will NOT copy SWISSINFO/SOC_SO/SOC_SO-1942.jsonl.bz2 to SWISSINFO/SOC_SO/SOC_SO-1942.jsonl.bz2 - same key or no copy
# construct_dest_key - found_provider is not None (SWISSINFO), skipping, and returning key as-is: SWISSINFO/SOC_SO/SOC_SO-1943.jsonl.bz2
#     will NOT copy SWISSINFO/SOC_SO/SOC_SO-1943.jsonl.bz2 to SWISSINFO/SOC_SO/SOC_SO-1943.jsonl.bz2 - same key or no copy
# construct_dest_key - found_provider is not None (SWISSINFO), skipping, and returning key as-is: SWISSINFO/SOC_SO/SOC_SO-1944.jsonl.bz2
#     will NOT copy SWISSINFO/SOC_SO/SOC_SO-1944.jsonl.bz2 to SWISSINFO/SOC_SO/SOC_SO-1944.jsonl.bz2 - same key or no copy
# construct_dest_key - found_provider is not None (SWISSINFO), skipping, and returning key as-is: SWISSINFO/SOC_SO/SOC_SO-1945.jsonl.bz2
#     will NOT copy SWISSINFO/SOC_SO/SOC_SO-1945.jsonl.bz2 to SWISSINFO/SOC_SO/SOC_SO-1945.jsonl.bz2 - same key or no copy
# Found new alias in key - Now processing alias SOC_TH - provider = SWISSINFO
# construct_dest_key - found_provider is not None (SWISSINFO), skipping, and returning key as-is: SWISSINFO/SOC_TH/SOC_TH-1941.jsonl.bz2
#     will NOT copy SWISSINFO/SOC_TH/SOC_TH-1941.jsonl.bz2 to SWISSINFO/SOC_TH/SOC_TH-1941.jsonl.bz2 - same key or no copy
# construct_dest_key - found_provider is not None (SWISSINFO), skipping, and returning key as-is: SWISSINFO/SOC_TH/SOC_TH-1943.jsonl.bz2
#     will NOT copy SWISSINFO/SOC_TH/SOC_TH-1943.jsonl.bz2 to SWISSINFO/SOC_TH/SOC_TH-1943.jsonl.bz2 - same key or no copy
# construct_dest_key - found_provider is not None (SWISSINFO), skipping, and returning key as-is: SWISSINFO/SOC_TH/SOC_TH-1944.jsonl.bz2
#     will NOT copy SWISSINFO/SOC_TH/SOC_TH-1944.jsonl.bz2 to SWISSINFO/SOC_TH/SOC_TH-1944.jsonl.bz2 - same key or no copy
# construct_dest_key - found_provider is not None (SWISSINFO), skipping, and returning key as-is: SWISSINFO/SOC_TH/SOC_TH-1945.jsonl.bz2
#     will NOT copy SWISSINFO/SOC_TH/SOC_TH-1945.jsonl.bz2 to SWISSINFO/SOC_TH/SOC_TH-1945.jsonl.bz2 - same key or no copy
# Found new alias in key - Now processing alias SOC_VS - provider = SWISSINFO
# construct_dest_key - found_provider is not None (SWISSINFO), skipping, and returning key as-is: SWISSINFO/SOC_VS/SOC_VS-1943.jsonl.bz2
#     will NOT copy SWISSINFO/SOC_VS/SOC_VS-1943.jsonl.bz2 to SWISSINFO/SOC_VS/SOC_VS-1943.jsonl.bz2 - same key or no copy
# construct_dest_key - found_provider is not None (SWISSINFO), skipping, and returning key as-is: SWISSINFO/SOC_VS/SOC_VS-1944.jsonl.bz2
#     will NOT copy SWISSINFO/SOC_VS/SOC_VS-1944.jsonl.bz2 to SWISSINFO/SOC_VS/SOC_VS-1944.jsonl.bz2 - same key or no copy
# Found new alias in key - Now processing alias TouSuIl - provider = BCUL
# Found new alias in key - Now processing alias VDR - provider = SNL
# Found new alias in key - Now processing alias VHT - provider = SNL
# Found new alias in key - Now processing alias VVS - provider = BCUL
# Found new alias in key - Now processing alias VVS1 - provider = BCUL
# Found new alias in key - Now processing alias WHD - provider = SNL
# Found new alias in key - Now processing alias ZBT - provider = SNL
# Found new alias in key - Now processing alias actionfem - provider = BNL
# Found new alias in key - Now processing alias arbeitgeber - provider = SWA
# Found new alias in key - Now processing alias armeteufel - provider = BNL
# Found new alias in key - Now processing alias avenirgdl - provider = BNL
# Found new alias in key - Now processing alias buergerbeamten - provider = BNL
# Found new alias in key - Now processing alias courriergdl - provider = BNL
# Found new alias in key - Now processing alias deletz1893 - provider = BNL
# Found new alias in key - Now processing alias demitock - provider = BNL
# Found new alias in key - Now processing alias diekwochen - provider = BNL
# Found new alias in key - Now processing alias dunioun - provider = BNL
# Found new alias in key - Now processing alias esta - provider = BCUL
# Found new alias in key - Now processing alias excelsior - provider = BNF
# Found new alias in key - Now processing alias gazgrdlux - provider = BNL
# Found new alias in key - Now processing alias handelsztg - provider = SWA
# Found new alias in key - Now processing alias indeplux - provider = BNL
# Found new alias in key - Now processing alias jdpl - provider = BNF-EN
# Found new alias in key - Now processing alias kommmit - provider = BNL
# Found new alias in key - Now processing alias lafronde - provider = BNF
# Found new alias in key - Now processing alias landwortbild - provider = BNL
# Found new alias in key - Now processing alias legaulois - provider = BNF-EN
# Found new alias in key - Now processing alias lematin - provider = BNF-EN
# Found new alias in key - Now processing alias lepetitparisien - provider = BNF-EN
# Found new alias in key - Now processing alias lepji - provider = BNF-EN
# Found new alias in key - Now processing alias lunion - provider = BNL
# Found new alias in key - Now processing alias luxembourg1935 - provider = BNL
# Found new alias in key - Now processing alias luxland - provider = BNL
# Found new alias in key - Now processing alias luxwort - provider = BNL
# Found new alias in key - Now processing alias luxzeit1844 - provider = BNL
# Found new alias in key - Now processing alias luxzeit1858 - provider = BNL
# Found new alias in key - Now processing alias marieclaire - provider = BNF
# Found new alias in key - Now processing alias obermosel - provider = BNL
# Found new alias in key - Now processing alias oecaen - provider = BNF-EN
# Found new alias in key - Now processing alias oerennes - provider = BNF-EN
# Found new alias in key - Now processing alias oeuvre - provider = BNF
# Found new alias in key - Now processing alias onsjongen - provider = BNL
# Found new alias in key - Now processing alias ouistiti - provider = BCUL
# Found new alias in key - Now processing alias schmiede - provider = BNL
# Found new alias in key - Now processing alias tageblatt - provider = BNL
# Found new alias in key - Now processing alias volkfreu1869 - provider = BNL
# Found new alias in key - Now processing alias waechtersauer - provider = BNL
# Found new alias in key - Now processing alias waeschfra - provider = BNL

# %%
s3_c.copy_object(
    Bucket=dest_bucket,
    Key="INA/CFCE/CFCE-1996.jsonl.bz2",
    CopySource={"Bucket": src_bucket, "Key": "CFCE/CFCE-1996.jsonl.bz2"},
    MetadataDirective='COPY',
)
# Out:
# {'ResponseMetadata': {'RequestId': 'tx000002cbd1a96b3456430-006863f94c-2487f741f-default',
#   'HostId': '',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'server': 'nginx',
#    'date': 'Tue, 01 Jul 2025 15:05:48 GMT',
#    'content-type': 'application/xml',
#    'transfer-encoding': 'chunked',
#    'connection': 'keep-alive',
#    'x-amz-request-id': 'tx000002cbd1a96b3456430-006863f94c-2487f741f-default',
#    'strict-transport-security': 'max-age=31536000; includeSubdomains'},
#   'RetryAttempts': 0},
#  'CopyObjectResult': {'ETag': '49d9c849dfdf53d9167d6075789888b2',
#   'LastModified': datetime.datetime(2025, 7, 1, 15, 5, 48, 728000, tzinfo=tzutc())}}

# %%
existing_metadata = s3_c.head_object(Bucket=src_bucket, Key="CFCE/CFCE-1996.jsonl.bz2").get("Metadata", {})
existing_metadata = s3_c.head_object(Bucket=src_bucket, Key="SOC_VS/SOC_VS-1944.jsonl.bz2").get("Metadata", {})
existing_metadata
# Out:
# {}

# %%
src_bucket
# Out:
# '120-rebuilt-sandbox'

# %%
s3_c = get_s3_client()
try:
    existing_object = s3_c.head_object(Bucket=src_bucket, Key="BCUL/ACI/ACI-1832.jsonl.bz2")
    print(f"key found!: {existing_object}")
except Exception as e:
    print("key not found")
# Out:
# key found!: {'ResponseMetadata': {'RequestId': 'tx000001ec57d7d744ddffd-006863ffed-2487f759b-default', 'HostId': '', 'HTTPStatusCode': 200, 'HTTPHeaders': {'server': 'nginx', 'date': 'Tue, 01 Jul 2025 15:34:05 GMT', 'content-type': 'binary/octet-stream', 'content-length': '271664', 'connection': 'keep-alive', 'accept-ranges': 'bytes', 'last-modified': 'Tue, 01 Jul 2025 15:21:49 GMT', 'x-rgw-object-type': 'Normal', 'etag': '"3a187e2b4ce700bc508e856c79c59887"', 'x-amz-meta-impresso-last-ts': '2024-03-26T16:28:05Z', 'x-amz-meta-mtime': '1711470487.908', 'x-amz-request-id': 'tx000001ec57d7d744ddffd-006863ffed-2487f759b-default', 'strict-transport-security': 'max-age=31536000; includeSubdomains'}, 'RetryAttempts': 0}, 'AcceptRanges': 'bytes', 'LastModified': datetime.datetime(2025, 7, 1, 15, 21, 49, tzinfo=tzutc()), 'ContentLength': 271664, 'ETag': '"3a187e2b4ce700bc508e856c79c59887"', 'ContentType': 'binary/octet-stream', 'Metadata': {'impresso-last-ts': '2024-03-26T16:28:05Z', 'mtime': '1711470487.908'}}

# %%
s3_c.copy_object(
    Bucket=dest_bucket,
    Key="SWISSINFO/SOC_VS/SOC_VS-1944.jsonl.bz2",
    CopySource={"Bucket": src_bucket, "Key": "SOC_VS/SOC_VS-1944.jsonl.bz2"},
    MetadataDirective='COPY',
)
# Out:
# {'ResponseMetadata': {'RequestId': 'tx00000aaf97c1716a06036-006863f9dc-2487f774e-default',
#   'HostId': '',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'server': 'nginx',
#    'date': 'Tue, 01 Jul 2025 15:08:12 GMT',
#    'content-type': 'application/xml',
#    'transfer-encoding': 'chunked',
#    'connection': 'keep-alive',
#    'x-amz-request-id': 'tx00000aaf97c1716a06036-006863f9dc-2487f774e-default',
#    'strict-transport-security': 'max-age=31536000; includeSubdomains'},
#   'RetryAttempts': 0},
#  'CopyObjectResult': {'ETag': 'f6ed914ee97668222feff2b52f7b0077',
#   'LastModified': datetime.datetime(2025, 7, 1, 15, 8, 12, 896000, tzinfo=tzutc())}}

# %%
paginator = s3_c.get_paginator("list_objects_v2")

page_iterator = paginator.paginate(Bucket=src_bucket, Prefix=exact_partition)

current_alias = None
provider = None
for page in page_iterator:
    for obj in page.get("Contents", []):
        key = obj["Key"]
        #print(f"        key: {key}, key.split('/')[-2]: {key.split('/')[-2]}")
        if key[:-1]==exact_partition:
            print(f"partition: {key}")
        elif not key.endswith(".jsonl.bz2") and key.endswith("/"):
            print(f"media_alias: {key}")
            current_alias = key.split('/')[-2]
            provider = get_provider_for_alias(current_alias)
            print(f"Now processing alias {current_alias} - provider = {provider}")
        elif key.endswith(".jsonl.bz2"):

            # check if we have now changed Alias or provider
            new_alias, found_prov = get_alias_from_path(key, exact_partition)
            if current_alias!=new_alias:
                current_alias=new_alias
                provider = get_provider_for_alias(current_alias)
                print(f"Found new alias in key - Now processing alias {current_alias} - provider = {provider}")


            #print(f"    file key: {key} - current_alias: {current_alias}, provider={provider}, exact_partition: {exact_partition}.")
            dest_key = construct_dest_key(key, provider, exact_partition, current_alias)
            print(f"    file key: will copy {key} here: {dest_key}")
            if False:
                with disable_interrupts():
                    s3_c.copy_object(
                        Bucket=dest_bucket,
                        Key=dest_key,
                        CopySource={"Bucket": bucket, "Key": key},
                        Metadata=updated_metadata,
                        MetadataDirective="REPLACE",
                        ContentType=head.get("ContentType", "application/octet-stream"),
                    )
        else:
            print(f"    -> another file: {key}")
# Out:
# partition: langident/langident_v1-4-4/
# media_alias: langident/langident_v1-4-4/ACI/
# Now processing alias ACI - provider = BCUL
# og_partition : langident/langident_v1-4-4, current_alias=ACI
#     file key: will copy langident/langident_v1-4-4/ACI/ACI-1832.jsonl.bz2 here: langident/langident_v1-4-4/BCUL/ACI/ACI-1832.jsonl.bz2
# media_alias: langident/langident_v1-4-4/AV/
# Now processing alias AV - provider = BCUL
# og_partition : langident/langident_v1-4-4, current_alias=AV
#     file key: will copy langident/langident_v1-4-4/AV/AV-1880.jsonl.bz2 here: langident/langident_v1-4-4/BCUL/AV/AV-1880.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=AV
#     file key: will copy langident/langident_v1-4-4/AV/AV-1881.jsonl.bz2 here: langident/langident_v1-4-4/BCUL/AV/AV-1881.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=AV
#     file key: will copy langident/langident_v1-4-4/AV/AV-1886.jsonl.bz2 here: langident/langident_v1-4-4/BCUL/AV/AV-1886.jsonl.bz2
# media_alias: langident/langident_v1-4-4/BDC/
# Now processing alias BDC - provider = SNL
# og_partition : langident/langident_v1-4-4, current_alias=BDC
#     file key: will copy langident/langident_v1-4-4/BDC/BDC-1839.jsonl.bz2 here: langident/langident_v1-4-4/SNL/BDC/BDC-1839.jsonl.bz2
# media_alias: langident/langident_v1-4-4/BLB/
# Now processing alias BLB - provider = SNL
# og_partition : langident/langident_v1-4-4, current_alias=BLB
#     file key: will copy langident/langident_v1-4-4/BLB/BLB-1845.jsonl.bz2 here: langident/langident_v1-4-4/SNL/BLB/BLB-1845.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=BLB
#     file key: will copy langident/langident_v1-4-4/BLB/BLB-1846.jsonl.bz2 here: langident/langident_v1-4-4/SNL/BLB/BLB-1846.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=BLB
#     file key: will copy langident/langident_v1-4-4/BLB/BLB-1847.jsonl.bz2 here: langident/langident_v1-4-4/SNL/BLB/BLB-1847.jsonl.bz2
# media_alias: langident/langident_v1-4-4/BNN/
# Now processing alias BNN - provider = SNL
# og_partition : langident/langident_v1-4-4, current_alias=BNN
#     file key: will copy langident/langident_v1-4-4/BNN/BNN-1885.jsonl.bz2 here: langident/langident_v1-4-4/SNL/BNN/BNN-1885.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=BNN
#     file key: will copy langident/langident_v1-4-4/BNN/BNN-1886.jsonl.bz2 here: langident/langident_v1-4-4/SNL/BNN/BNN-1886.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=BNN
#     file key: will copy langident/langident_v1-4-4/BNN/BNN-1887.jsonl.bz2 here: langident/langident_v1-4-4/SNL/BNN/BNN-1887.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=BNN
#     file key: will copy langident/langident_v1-4-4/BNN/BNN-1888.jsonl.bz2 here: langident/langident_v1-4-4/SNL/BNN/BNN-1888.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=BNN
#     file key: will copy langident/langident_v1-4-4/BNN/BNN-1889.jsonl.bz2 here: langident/langident_v1-4-4/SNL/BNN/BNN-1889.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=BNN
#     file key: will copy langident/langident_v1-4-4/BNN/BNN-1890.jsonl.bz2 here: langident/langident_v1-4-4/SNL/BNN/BNN-1890.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=BNN
#     file key: will copy langident/langident_v1-4-4/BNN/BNN-1891.jsonl.bz2 here: langident/langident_v1-4-4/SNL/BNN/BNN-1891.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=BNN
#     file key: will copy langident/langident_v1-4-4/BNN/BNN-1892.jsonl.bz2 here: langident/langident_v1-4-4/SNL/BNN/BNN-1892.jsonl.bz2
# media_alias: langident/langident_v1-4-4/Bombe/
# Now processing alias Bombe - provider = BCUL
# og_partition : langident/langident_v1-4-4, current_alias=Bombe
#     file key: will copy langident/langident_v1-4-4/Bombe/Bombe-1889.jsonl.bz2 here: langident/langident_v1-4-4/BCUL/Bombe/Bombe-1889.jsonl.bz2
# media_alias: langident/langident_v1-4-4/CDV/
# Now processing alias CDV - provider = SNL
# og_partition : langident/langident_v1-4-4, current_alias=CDV
#     file key: will copy langident/langident_v1-4-4/CDV/CDV-1843.jsonl.bz2 here: langident/langident_v1-4-4/SNL/CDV/CDV-1843.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=CDV
#     file key: will copy langident/langident_v1-4-4/CDV/CDV-1844.jsonl.bz2 here: langident/langident_v1-4-4/SNL/CDV/CDV-1844.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=CDV
#     file key: will copy langident/langident_v1-4-4/CDV/CDV-1849.jsonl.bz2 here: langident/langident_v1-4-4/SNL/CDV/CDV-1849.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=CDV
#     file key: will copy langident/langident_v1-4-4/CDV/CDV-1850.jsonl.bz2 here: langident/langident_v1-4-4/SNL/CDV/CDV-1850.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=CDV
#     file key: will copy langident/langident_v1-4-4/CDV/CDV-1851.jsonl.bz2 here: langident/langident_v1-4-4/SNL/CDV/CDV-1851.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=CDV
#     file key: will copy langident/langident_v1-4-4/CDV/CDV-1852.jsonl.bz2 here: langident/langident_v1-4-4/SNL/CDV/CDV-1852.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=CDV
#     file key: will copy langident/langident_v1-4-4/CDV/CDV-1853.jsonl.bz2 here: langident/langident_v1-4-4/SNL/CDV/CDV-1853.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=CDV
#     file key: will copy langident/langident_v1-4-4/CDV/CDV-1854.jsonl.bz2 here: langident/langident_v1-4-4/SNL/CDV/CDV-1854.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=CDV
#     file key: will copy langident/langident_v1-4-4/CDV/CDV-1855.jsonl.bz2 here: langident/langident_v1-4-4/SNL/CDV/CDV-1855.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=CDV
#     file key: will copy langident/langident_v1-4-4/CDV/CDV-1856.jsonl.bz2 here: langident/langident_v1-4-4/SNL/CDV/CDV-1856.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=CDV
#     file key: will copy langident/langident_v1-4-4/CDV/CDV-1857.jsonl.bz2 here: langident/langident_v1-4-4/SNL/CDV/CDV-1857.jsonl.bz2
# media_alias: langident/langident_v1-4-4/CL/
# Now processing alias CL - provider = BCUL
# og_partition : langident/langident_v1-4-4, current_alias=CL
#     file key: will copy langident/langident_v1-4-4/CL/CL-1882.jsonl.bz2 here: langident/langident_v1-4-4/BCUL/CL/CL-1882.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=CL
#     file key: will copy langident/langident_v1-4-4/CL/CL-1883.jsonl.bz2 here: langident/langident_v1-4-4/BCUL/CL/CL-1883.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=CL
#     file key: will copy langident/langident_v1-4-4/CL/CL-1884.jsonl.bz2 here: langident/langident_v1-4-4/BCUL/CL/CL-1884.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=CL
#     file key: will copy langident/langident_v1-4-4/CL/CL-1885.jsonl.bz2 here: langident/langident_v1-4-4/BCUL/CL/CL-1885.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=CL
#     file key: will copy langident/langident_v1-4-4/CL/CL-1886.jsonl.bz2 here: langident/langident_v1-4-4/BCUL/CL/CL-1886.jsonl.bz2
# media_alias: langident/langident_v1-4-4/CON/
# Now processing alias CON - provider = SNL
# og_partition : langident/langident_v1-4-4, current_alias=CON
#     file key: will copy langident/langident_v1-4-4/CON/CON-1902.jsonl.bz2 here: langident/langident_v1-4-4/SNL/CON/CON-1902.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=CON
#     file key: will copy langident/langident_v1-4-4/CON/CON-1903.jsonl.bz2 here: langident/langident_v1-4-4/SNL/CON/CON-1903.jsonl.bz2
# media_alias: langident/langident_v1-4-4/Cancoire/
# Now processing alias Cancoire - provider = BCUL
# og_partition : langident/langident_v1-4-4, current_alias=Cancoire
#     file key: will copy langident/langident_v1-4-4/Cancoire/Cancoire-1898.jsonl.bz2 here: langident/langident_v1-4-4/BCUL/Cancoire/Cancoire-1898.jsonl.bz2
# media_alias: langident/langident_v1-4-4/Castigat/
# Now processing alias Castigat - provider = BCUL
# og_partition : langident/langident_v1-4-4, current_alias=Castigat
#     file key: will copy langident/langident_v1-4-4/Castigat/Castigat-1879.jsonl.bz2 here: langident/langident_v1-4-4/BCUL/Castigat/Castigat-1879.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=Castigat
#     file key: will copy langident/langident_v1-4-4/Castigat/Castigat-1880.jsonl.bz2 here: langident/langident_v1-4-4/BCUL/Castigat/Castigat-1880.jsonl.bz2
# media_alias: langident/langident_v1-4-4/Charivari/
# Now processing alias Charivari - provider = BCUL
# og_partition : langident/langident_v1-4-4, current_alias=Charivari
#     file key: will copy langident/langident_v1-4-4/Charivari/Charivari-1839.jsonl.bz2 here: langident/langident_v1-4-4/BCUL/Charivari/Charivari-1839.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=Charivari
#     file key: will copy langident/langident_v1-4-4/Charivari/Charivari-1840.jsonl.bz2 here: langident/langident_v1-4-4/BCUL/Charivari/Charivari-1840.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=Charivari
#     file key: will copy langident/langident_v1-4-4/Charivari/Charivari-1841.jsonl.bz2 here: langident/langident_v1-4-4/BCUL/Charivari/Charivari-1841.jsonl.bz2
# media_alias: langident/langident_v1-4-4/CharivariCH/
# Now processing alias CharivariCH - provider = BCUL
# og_partition : langident/langident_v1-4-4, current_alias=CharivariCH
#     file key: will copy langident/langident_v1-4-4/CharivariCH/CharivariCH-1875.jsonl.bz2 here: langident/langident_v1-4-4/BCUL/CharivariCH/CharivariCH-1875.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=CharivariCH
#     file key: will copy langident/langident_v1-4-4/CharivariCH/CharivariCH-1876.jsonl.bz2 here: langident/langident_v1-4-4/BCUL/CharivariCH/CharivariCH-1876.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=CharivariCH
#     file key: will copy langident/langident_v1-4-4/CharivariCH/CharivariCH-1877.jsonl.bz2 here: langident/langident_v1-4-4/BCUL/CharivariCH/CharivariCH-1877.jsonl.bz2
# media_alias: langident/langident_v1-4-4/Croquis/
# Now processing alias Croquis - provider = BCUL
# og_partition : langident/langident_v1-4-4, current_alias=Croquis
#     file key: will copy langident/langident_v1-4-4/Croquis/Croquis-1884.jsonl.bz2 here: langident/langident_v1-4-4/BCUL/Croquis/Croquis-1884.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=Croquis
#     file key: will copy langident/langident_v1-4-4/Croquis/Croquis-1885.jsonl.bz2 here: langident/langident_v1-4-4/BCUL/Croquis/Croquis-1885.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=Croquis
#     file key: will copy langident/langident_v1-4-4/Croquis/Croquis-1886.jsonl.bz2 here: langident/langident_v1-4-4/BCUL/Croquis/Croquis-1886.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=Croquis
#     file key: will copy langident/langident_v1-4-4/Croquis/Croquis-1887.jsonl.bz2 here: langident/langident_v1-4-4/BCUL/Croquis/Croquis-1887.jsonl.bz2
# media_alias: langident/langident_v1-4-4/DFS/
# Now processing alias DFS - provider = SNL
# og_partition : langident/langident_v1-4-4, current_alias=DFS
#     file key: will copy langident/langident_v1-4-4/DFS/DFS-1814.jsonl.bz2 here: langident/langident_v1-4-4/SNL/DFS/DFS-1814.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=DFS
#     file key: will copy langident/langident_v1-4-4/DFS/DFS-1815.jsonl.bz2 here: langident/langident_v1-4-4/SNL/DFS/DFS-1815.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=DFS
#     file key: will copy langident/langident_v1-4-4/DFS/DFS-1816.jsonl.bz2 here: langident/langident_v1-4-4/SNL/DFS/DFS-1816.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=DFS
#     file key: will copy langident/langident_v1-4-4/DFS/DFS-1817.jsonl.bz2 here: langident/langident_v1-4-4/SNL/DFS/DFS-1817.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=DFS
#     file key: will copy langident/langident_v1-4-4/DFS/DFS-1818.jsonl.bz2 here: langident/langident_v1-4-4/SNL/DFS/DFS-1818.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=DFS
#     file key: will copy langident/langident_v1-4-4/DFS/DFS-1819.jsonl.bz2 here: langident/langident_v1-4-4/SNL/DFS/DFS-1819.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=DFS
#     file key: will copy langident/langident_v1-4-4/DFS/DFS-1820.jsonl.bz2 here: langident/langident_v1-4-4/SNL/DFS/DFS-1820.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=DFS
#     file key: will copy langident/langident_v1-4-4/DFS/DFS-1821.jsonl.bz2 here: langident/langident_v1-4-4/SNL/DFS/DFS-1821.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=DFS
#     file key: will copy langident/langident_v1-4-4/DFS/DFS-1822.jsonl.bz2 here: langident/langident_v1-4-4/SNL/DFS/DFS-1822.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=DFS
#     file key: will copy langident/langident_v1-4-4/DFS/DFS-1823.jsonl.bz2 here: langident/langident_v1-4-4/SNL/DFS/DFS-1823.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=DFS
#     file key: will copy langident/langident_v1-4-4/DFS/DFS-1824.jsonl.bz2 here: langident/langident_v1-4-4/SNL/DFS/DFS-1824.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=DFS
#     file key: will copy langident/langident_v1-4-4/DFS/DFS-1825.jsonl.bz2 here: langident/langident_v1-4-4/SNL/DFS/DFS-1825.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=DFS
#     file key: will copy langident/langident_v1-4-4/DFS/DFS-1826.jsonl.bz2 here: langident/langident_v1-4-4/SNL/DFS/DFS-1826.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=DFS
#     file key: will copy langident/langident_v1-4-4/DFS/DFS-1827.jsonl.bz2 here: langident/langident_v1-4-4/SNL/DFS/DFS-1827.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=DFS
#     file key: will copy langident/langident_v1-4-4/DFS/DFS-1828.jsonl.bz2 here: langident/langident_v1-4-4/SNL/DFS/DFS-1828.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=DFS
#     file key: will copy langident/langident_v1-4-4/DFS/DFS-1829.jsonl.bz2 here: langident/langident_v1-4-4/SNL/DFS/DFS-1829.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=DFS
#     file key: will copy langident/langident_v1-4-4/DFS/DFS-1830.jsonl.bz2 here: langident/langident_v1-4-4/SNL/DFS/DFS-1830.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=DFS
#     file key: will copy langident/langident_v1-4-4/DFS/DFS-1831.jsonl.bz2 here: langident/langident_v1-4-4/SNL/DFS/DFS-1831.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=DFS
#     file key: will copy langident/langident_v1-4-4/DFS/DFS-1832.jsonl.bz2 here: langident/langident_v1-4-4/SNL/DFS/DFS-1832.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=DFS
#     file key: will copy langident/langident_v1-4-4/DFS/DFS-1833.jsonl.bz2 here: langident/langident_v1-4-4/SNL/DFS/DFS-1833.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=DFS
#     file key: will copy langident/langident_v1-4-4/DFS/DFS-1834.jsonl.bz2 here: langident/langident_v1-4-4/SNL/DFS/DFS-1834.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=DFS
#     file key: will copy langident/langident_v1-4-4/DFS/DFS-1835.jsonl.bz2 here: langident/langident_v1-4-4/SNL/DFS/DFS-1835.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=DFS
#     file key: will copy langident/langident_v1-4-4/DFS/DFS-1836.jsonl.bz2 here: langident/langident_v1-4-4/SNL/DFS/DFS-1836.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=DFS
#     file key: will copy langident/langident_v1-4-4/DFS/DFS-1837.jsonl.bz2 here: langident/langident_v1-4-4/SNL/DFS/DFS-1837.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=DFS
#     file key: will copy langident/langident_v1-4-4/DFS/DFS-1838.jsonl.bz2 here: langident/langident_v1-4-4/SNL/DFS/DFS-1838.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=DFS
#     file key: will copy langident/langident_v1-4-4/DFS/DFS-1839.jsonl.bz2 here: langident/langident_v1-4-4/SNL/DFS/DFS-1839.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=DFS
#     file key: will copy langident/langident_v1-4-4/DFS/DFS-1840.jsonl.bz2 here: langident/langident_v1-4-4/SNL/DFS/DFS-1840.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=DFS
#     file key: will copy langident/langident_v1-4-4/DFS/DFS-1841.jsonl.bz2 here: langident/langident_v1-4-4/SNL/DFS/DFS-1841.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=DFS
#     file key: will copy langident/langident_v1-4-4/DFS/DFS-1842.jsonl.bz2 here: langident/langident_v1-4-4/SNL/DFS/DFS-1842.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=DFS
#     file key: will copy langident/langident_v1-4-4/DFS/DFS-1843.jsonl.bz2 here: langident/langident_v1-4-4/SNL/DFS/DFS-1843.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=DFS
#     file key: will copy langident/langident_v1-4-4/DFS/DFS-1844.jsonl.bz2 here: langident/langident_v1-4-4/SNL/DFS/DFS-1844.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=DFS
#     file key: will copy langident/langident_v1-4-4/DFS/DFS-1845.jsonl.bz2 here: langident/langident_v1-4-4/SNL/DFS/DFS-1845.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=DFS
#     file key: will copy langident/langident_v1-4-4/DFS/DFS-1846.jsonl.bz2 here: langident/langident_v1-4-4/SNL/DFS/DFS-1846.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=DFS
#     file key: will copy langident/langident_v1-4-4/DFS/DFS-1847.jsonl.bz2 here: langident/langident_v1-4-4/SNL/DFS/DFS-1847.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=DFS
#     file key: will copy langident/langident_v1-4-4/DFS/DFS-1848.jsonl.bz2 here: langident/langident_v1-4-4/SNL/DFS/DFS-1848.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=DFS
#     file key: will copy langident/langident_v1-4-4/DFS/DFS-1849.jsonl.bz2 here: langident/langident_v1-4-4/SNL/DFS/DFS-1849.jsonl.bz2
# media_alias: langident/langident_v1-4-4/DLE/
# Now processing alias DLE - provider = SNL
# og_partition : langident/langident_v1-4-4, current_alias=DLE
#     file key: will copy langident/langident_v1-4-4/DLE/DLE-1909.jsonl.bz2 here: langident/langident_v1-4-4/SNL/DLE/DLE-1909.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=DLE
#     file key: will copy langident/langident_v1-4-4/DLE/DLE-1910.jsonl.bz2 here: langident/langident_v1-4-4/SNL/DLE/DLE-1910.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=DLE
#     file key: will copy langident/langident_v1-4-4/DLE/DLE-1911.jsonl.bz2 here: langident/langident_v1-4-4/SNL/DLE/DLE-1911.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=DLE
#     file key: will copy langident/langident_v1-4-4/DLE/DLE-1912.jsonl.bz2 here: langident/langident_v1-4-4/SNL/DLE/DLE-1912.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=DLE
#     file key: will copy langident/langident_v1-4-4/DLE/DLE-1913.jsonl.bz2 here: langident/langident_v1-4-4/SNL/DLE/DLE-1913.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=DLE
#     file key: will copy langident/langident_v1-4-4/DLE/DLE-1914.jsonl.bz2 here: langident/langident_v1-4-4/SNL/DLE/DLE-1914.jsonl.bz2
# media_alias: langident/langident_v1-4-4/DTT/
# Now processing alias DTT - provider = SNL
# og_partition : langident/langident_v1-4-4, current_alias=DTT
#     file key: will copy langident/langident_v1-4-4/DTT/DTT-1935.jsonl.bz2 here: langident/langident_v1-4-4/SNL/DTT/DTT-1935.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=DTT
#     file key: will copy langident/langident_v1-4-4/DTT/DTT-1936.jsonl.bz2 here: langident/langident_v1-4-4/SNL/DTT/DTT-1936.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=DTT
#     file key: will copy langident/langident_v1-4-4/DTT/DTT-1937.jsonl.bz2 here: langident/langident_v1-4-4/SNL/DTT/DTT-1937.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=DTT
#     file key: will copy langident/langident_v1-4-4/DTT/DTT-1938.jsonl.bz2 here: langident/langident_v1-4-4/SNL/DTT/DTT-1938.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=DTT
#     file key: will copy langident/langident_v1-4-4/DTT/DTT-1939.jsonl.bz2 here: langident/langident_v1-4-4/SNL/DTT/DTT-
jsonl.bz2 here: langident/langident_v1-4-4/SNL/EXP/EXP-1824.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=EXP
#     file key: will copy langident/langident_v1-4-4/EXP/EXP-1825.jsonl.bz2 here: langident/langident_v1-4-4/SNL/EXP/EXP-1825.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=EXP
#     file key: will copy langident/langident_v1-4-4/EXP/EXP-1826.jsonl.bz2 here: langident/langident_v1-4-4/SNL/EXP/EXP-1826.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=EXP
#     file key: will copy langident/langident_v1-4-4/EXP/EXP-1827.jsonl.bz2 here: langident/langident_v1-4-4/SNL/EXP/EXP-1827.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=EXP
#     file key: will copy langident/langident_v1-4-4/EXP/EXP-1828.jsonl.bz2 here: langident/langident_v1-4-4/SNL/EXP/EXP-1828.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=EXP
#     file key: will copy langident/langident_v1-4-4/EXP/EXP-1829.jsonl.bz2 here: langident/langident_v1-4-4/SNL/EXP/EXP-1829.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=EXP
#     file key: will copy langident/langident_v1-4-4/EXP/EXP-1830.jsonl.bz2 here: langident/langident_v1-4-4/SNL/EXP/EXP-1830.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=EXP
#     file key: will copy langident/langident_v1-4-4/EXP/EXP-1831.jsonl.bz2 here: langident/langident_v1-4-4/SNL/EXP/EXP-1831.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=EXP
#     file key: will copy langident/langident_v1-4-4/EXP/EXP-1832.jsonl.bz2 here: langident/langident_v1-4-4/SNL/EXP/EXP-1832.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=EXP
#     file key: will copy langident/langident_v1-4-4/EXP/EXP-1833.jsonl.bz2 here: langident/langident_v1-4-4/SNL/EXP/EXP-1833.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=EXP
#     file key: will copy langident/langident_v1-4-4/EXP/EXP-1834.jsonl.bz2 here: langident/langident_v1-4-4/SNL/EXP/EXP-1834.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=EXP
#     file key: will copy langident/langident_v1-4-4/EXP/EXP-1835.jsonl.bz2 here: langident/langident_v1-4-4/SNL/EXP/EXP-1835.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=EXP
#     file key: will copy langident/langident_v1-4-4/EXP/EXP-1836.jsonl.bz2 here: langident/langident_v1-4-4/SNL/EXP/EXP-1836.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=EXP
#     file key: will copy langident/langident_v1-4-4/EXP/EXP-1837.jsonl.bz2 here: langident/langident_v1-4-4/SNL/EXP/EXP-1837.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=EXP
#     file key: will copy langident/langident_v1-4-4/EXP/EXP-1838.jsonl.bz2 here: langident/langident_v1-4-4/SNL/EXP/EXP-1838.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=EXP
#     file key: will copy langident/langident_v1-4-4/EXP/EXP-1839.jsonl.bz2 here: langident/langident_v1-4-4/SNL/EXP/EXP-1839.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=EXP
#     file key: will copy langident/langident_v1-4-4/EXP/EXP-1840.jsonl.bz2 here: langident/langident_v1-4-4/SNL/EXP/EXP-1840.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=EXP
#     file key: will copy langident/langident_v1-4-4/EXP/EXP-1841.jsonl.bz2 here: langident/langident_v1-4-4/SNL/EXP/EXP-1841.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=EXP
#     file key: will copy langident/langident_v1-4-4/EXP/EXP-1842.jsonl.bz2 here: langident/langident_v1-4-4/SNL/EXP/EXP-1842.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=EXP
#     file key: will copy langident/langident_v1-4-4/EXP/EXP-1843.jsonl.bz2 here: langident/langident_v1-4-4/SNL/EXP/EXP-1843.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=EXP
#     file key: will copy langident/langident_v1-4-4/EXP/EXP-1844.jsonl.bz2 here: langident/langident_v1-4-4/SNL/EXP/EXP-1844.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=EXP
#     file key: will copy langident/langident_v1-4-4/EXP/EXP-1845.jsonl.bz2 here: langident/langident_v1-4-4/SNL/EXP/EXP-1845.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=EXP
#     file key: will copy langident/langident_v1-4-4/EXP/EXP-1846.jsonl.bz2 here: langident/langident_v1-4-4/SNL/EXP/EXP-1846.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=EXP
#     file key: will copy langident/langident_v1-4-4/EXP/EXP-1847.jsonl.bz2 here: langident/langident_v1-4-4/SNL/EXP/EXP-1847.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=EXP
#     file key: will copy langident/langident_v1-4-4/EXP/EXP-1848.jsonl.bz2 here: langident/langident_v1-4-4/SNL/EXP/EXP-1848.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=EXP
#     file key: will copy langident/langident_v1-4-4/EXP/EXP-1849.jsonl.bz2 here: langident/langident_v1-4-4/SNL/EXP/EXP-1849.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=EXP
#     file key: will copy langident/langident_v1-4-4/EXP/EXP-1850.jsonl.bz2 here: langident/langident_v1-4-4/SNL/EXP/EXP-1850.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=EXP
#     file key: will copy langident/langident_v1-4-4/EXP/EXP-1851.jsonl.bz2 here: langident/langident_v1-4-4/SNL/EXP/EXP-1851.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=EXP
#     file key: will copy langident/langident_v1-4-4/EXP/EXP-1852.jsonl.bz2 here: langident/langident_v1-4-4/SNL/EXP/EXP-1852.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=EXP
#     file key: will copy langident/langident_v1-4-4/EXP/EXP-1853.jsonl.bz2 here: langident/langident_v1-4-4/SNL/EXP/EXP-1853.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=EXP
#     file key: will copy langident/langident_v1-4-4/EXP/EXP-1854.jsonl.bz2 here: langident/langident_v1-4-4/SNL/EXP/EXP-1854.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=EXP
#     file key: will copy langident/langident_v1-4-4/EXP/EXP-1855.jsonl.bz2 here: langident/langident_v1-4-4/SNL/EXP/EXP-1855.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=EXP
#     file key: will copy langident/langident_v1-4-4/EXP/EXP-1856.jsonl.bz2 here: langident/langident_v1-4-4/SNL/EXP/EXP-1856.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=EXP
#     file key: will copy langident/langident_v1-4-4/EXP/EXP-1857.jsonl.bz2 here: langident/langident_v1-4-4/SNL/EXP/EXP-1857.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=EXP
#     file key: will copy langident/langident_v1-4-4/EXP/EXP-1858.jsonl.bz2 here: langident/langident_v1-4-4/SNL/EXP/EXP-1858.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=EXP
#     file key: will copy langident/langident_v1-4-4/EXP/EXP-1859.jsonl.bz2 here: langident/langident_v1-4-4/SNL/EXP/EXP-1859.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=EXP
#     file key: will copy langident/langident_v1-4-4/EXP/EXP-1860.jsonl.bz2 here: langident/langident_v1-4-4/SNL/EXP/EXP-1860.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=EXP
#     file key: will copy langident/langident_v1-4-4/EXP/EXP-1861.jsonl.bz2 here: langident/langident_v1-4-4/SNL/EXP/EXP-1861.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=EXP
#     file key: will copy langident/langident_v1-4-4/EXP/EXP-1862.jsonl.bz2 here: langident/langident_v1-4-4/SNL/EXP/EXP-1862.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=EXP
#     file key: will copy langident/langident_v1-4-4/EXP/EXP-1863.jsonl.bz2 here: langident/langident_v1-4-4/SNL/EXP/EXP-1863.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=EXP
#     file key: will copy langident/langident_v1-4-4/EXP/EXP-1864.jsonl.bz2 here: langident/langident_v1-4-4/SNL/EXP/EXP-1864.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=EXP
#     file key: will copy langident/langident_v1-4-4/EXP/EXP-1865.jsonl.bz2 here: langident/langident_v1-4-4/SNL/EXP/EXP-1865.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=EXP
# ...
# og_partition : langident/langident_v1-4-4, current_alias=tageblatt
#     file key: will copy langident/langident_v1-4-4/tageblatt/tageblatt-1929.jsonl.bz2 here: langident/langident_v1-4-4/BNL/tageblatt/tageblatt-1929.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=tageblatt
#     file key: will copy langident/langident_v1-4-4/tageblatt/tageblatt-1930.jsonl.bz2 here: langident/langident_v1-4-4/BNL/tageblatt/tageblatt-1930.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=tageblatt
#     file key: will copy langident/langident_v1-4-4/tageblatt/tageblatt-1931.jsonl.bz2 here: langident/langident_v1-4-4/BNL/tageblatt/tageblatt-1931.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=tageblatt
#     file key: will copy langident/langident_v1-4-4/tageblatt/tageblatt-1932.jsonl.bz2 here: langident/langident_v1-4-4/BNL/tageblatt/tageblatt-1932.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=tageblatt
#     file key: will copy langident/langident_v1-4-4/tageblatt/tageblatt-1933.jsonl.bz2 here: langident/langident_v1-4-4/BNL/tageblatt/tageblatt-1933.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=tageblatt
#     file key: will copy langident/langident_v1-4-4/tageblatt/tageblatt-1934.jsonl.bz2 here: langident/langident_v1-4-4/BNL/tageblatt/tageblatt-1934.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=tageblatt
#     file key: will copy langident/langident_v1-4-4/tageblatt/tageblatt-1935.jsonl.bz2 here: langident/langident_v1-4-4/BNL/tageblatt/tageblatt-1935.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=tageblatt
#     file key: will copy langident/langident_v1-4-4/tageblatt/tageblatt-1936.jsonl.bz2 here: langident/langident_v1-4-4/BNL/tageblatt/tageblatt-1936.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=tageblatt
#     file key: will copy langident/langident_v1-4-4/tageblatt/tageblatt-1937.jsonl.bz2 here: langident/langident_v1-4-4/BNL/tageblatt/tageblatt-1937.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=tageblatt
#     file key: will copy langident/langident_v1-4-4/tageblatt/tageblatt-1938.jsonl.bz2 here: langident/langident_v1-4-4/BNL/tageblatt/tageblatt-1938.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=tageblatt
#     file key: will copy langident/langident_v1-4-4/tageblatt/tageblatt-1939.jsonl.bz2 here: langident/langident_v1-4-4/BNL/tageblatt/tageblatt-1939.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=tageblatt
#     file key: will copy langident/langident_v1-4-4/tageblatt/tageblatt-1940.jsonl.bz2 here: langident/langident_v1-4-4/BNL/tageblatt/tageblatt-1940.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=tageblatt
#     file key: will copy langident/langident_v1-4-4/tageblatt/tageblatt-1941.jsonl.bz2 here: langident/langident_v1-4-4/BNL/tageblatt/tageblatt-1941.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=tageblatt
#     file key: will copy langident/langident_v1-4-4/tageblatt/tageblatt-1942.jsonl.bz2 here: langident/langident_v1-4-4/BNL/tageblatt/tageblatt-1942.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=tageblatt
#     file key: will copy langident/langident_v1-4-4/tageblatt/tageblatt-1943.jsonl.bz2 here: langident/langident_v1-4-4/BNL/tageblatt/tageblatt-1943.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=tageblatt
#     file key: will copy langident/langident_v1-4-4/tageblatt/tageblatt-1944.jsonl.bz2 here: langident/langident_v1-4-4/BNL/tageblatt/tageblatt-1944.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=tageblatt
#     file key: will copy langident/langident_v1-4-4/tageblatt/tageblatt-1945.jsonl.bz2 here: langident/langident_v1-4-4/BNL/tageblatt/tageblatt-1945.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=tageblatt
#     file key: will copy langident/langident_v1-4-4/tageblatt/tageblatt-1946.jsonl.bz2 here: langident/langident_v1-4-4/BNL/tageblatt/tageblatt-1946.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=tageblatt
#     file key: will copy langident/langident_v1-4-4/tageblatt/tageblatt-1947.jsonl.bz2 here: langident/langident_v1-4-4/BNL/tageblatt/tageblatt-1947.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=tageblatt
#     file key: will copy langident/langident_v1-4-4/tageblatt/tageblatt-1948.jsonl.bz2 here: langident/langident_v1-4-4/BNL/tageblatt/tageblatt-1948.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=tageblatt
#     file key: will copy langident/langident_v1-4-4/tageblatt/tageblatt-1949.jsonl.bz2 here: langident/langident_v1-4-4/BNL/tageblatt/tageblatt-1949.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=tageblatt
#     file key: will copy langident/langident_v1-4-4/tageblatt/tageblatt-1950.jsonl.bz2 here: langident/langident_v1-4-4/BNL/tageblatt/tageblatt-1950.jsonl.bz2
# media_alias: langident/langident_v1-4-4/volkfreu1869/
# Now processing alias volkfreu1869 - provider = BNL
# og_partition : langident/langident_v1-4-4, current_alias=volkfreu1869
#     file key: will copy langident/langident_v1-4-4/volkfreu1869/volkfreu1869-1869.jsonl.bz2 here: langident/langident_v1-4-4/BNL/volkfreu1869/volkfreu1869-1869.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=volkfreu1869
#     file key: will copy langident/langident_v1-4-4/volkfreu1869/volkfreu1869-1870.jsonl.bz2 here: langident/langident_v1-4-4/BNL/volkfreu1869/volkfreu1869-1870.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=volkfreu1869
#     file key: will copy langident/langident_v1-4-4/volkfreu1869/volkfreu1869-1871.jsonl.bz2 here: langident/langident_v1-4-4/BNL/volkfreu1869/volkfreu1869-1871.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=volkfreu1869
#     file key: will copy langident/langident_v1-4-4/volkfreu1869/volkfreu1869-1872.jsonl.bz2 here: langident/langident_v1-4-4/BNL/volkfreu1869/volkfreu1869-1872.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=volkfreu1869
#     file key: will copy langident/langident_v1-4-4/volkfreu1869/volkfreu1869-1873.jsonl.bz2 here: langident/langident_v1-4-4/BNL/volkfreu1869/volkfreu1869-1873.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=volkfreu1869
#     file key: will copy langident/langident_v1-4-4/volkfreu1869/volkfreu1869-1874.jsonl.bz2 here: langident/langident_v1-4-4/BNL/volkfreu1869/volkfreu1869-1874.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=volkfreu1869
#     file key: will copy langident/langident_v1-4-4/volkfreu1869/volkfreu1869-1875.jsonl.bz2 here: langident/langident_v1-4-4/BNL/volkfreu1869/volkfreu1869-1875.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=volkfreu1869
#     file key: will copy langident/langident_v1-4-4/volkfreu1869/volkfreu1869-1876.jsonl.bz2 here: langident/langident_v1-4-4/BNL/volkfreu1869/volkfreu1869-1876.jsonl.bz2
# media_alias: langident/langident_v1-4-4/waechtersauer/
# Now processing alias waechtersauer - provider = BNL
# og_partition : langident/langident_v1-4-4, current_alias=waechtersauer
#     file key: will copy langident/langident_v1-4-4/waechtersauer/waechtersauer-1849.jsonl.bz2 here: langident/langident_v1-4-4/BNL/waechtersauer/waechtersauer-1849.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=waechtersauer
#     file key: will copy langident/langident_v1-4-4/waechtersauer/waechtersauer-1850.jsonl.bz2 here: langident/langident_v1-4-4/BNL/waechtersauer/waechtersauer-1850.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=waechtersauer
#     file key: will copy langident/langident_v1-4-4/waechtersauer/waechtersauer-1851.jsonl.bz2 here: langident/langident_v1-4-4/BNL/waechtersauer/waechtersauer-1851.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=waechtersauer
#     file key: will copy langident/langident_v1-4-4/waechtersauer/waechtersauer-1852.jsonl.bz2 here: langident/langident_v1-4-4/BNL/waechtersauer/waechtersauer-1852.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=waechtersauer
#     file key: will copy langident/langident_v1-4-4/waechtersauer/waechtersauer-1853.jsonl.bz2 here: langident/langident_v1-4-4/BNL/waechtersauer/waechtersauer-1853.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=waechtersauer
#     file key: will copy langident/langident_v1-4-4/waechtersauer/waechtersauer-1854.jsonl.bz2 here: langident/langident_v1-4-4/BNL/waechtersauer/waechtersauer-1854.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=waechtersauer
#     file key: will copy langident/langident_v1-4-4/waechtersauer/waechtersauer-1855.jsonl.bz2 here: langident/langident_v1-4-4/BNL/waechtersauer/waechtersauer-1855.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=waechtersauer
#     file key: will copy langident/langident_v1-4-4/waechtersauer/waechtersauer-1856.jsonl.bz2 here: langident/langident_v1-4-4/BNL/waechtersauer/waechtersauer-1856.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=waechtersauer
#     file key: will copy langident/langident_v1-4-4/waechtersauer/waechtersauer-1857.jsonl.bz2 here: langident/langident_v1-4-4/BNL/waechtersauer/waechtersauer-1857.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=waechtersauer
#     file key: will copy langident/langident_v1-4-4/waechtersauer/waechtersauer-1858.jsonl.bz2 here: langident/langident_v1-4-4/BNL/waechtersauer/waechtersauer-1858.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=waechtersauer
#     file key: will copy langident/langident_v1-4-4/waechtersauer/waechtersauer-1859.jsonl.bz2 here: langident/langident_v1-4-4/BNL/waechtersauer/waechtersauer-1859.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=waechtersauer
#     file key: will copy langident/langident_v1-4-4/waechtersauer/waechtersauer-1860.jsonl.bz2 here: langident/langident_v1-4-4/BNL/waechtersauer/waechtersauer-1860.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=waechtersauer
#     file key: will copy langident/langident_v1-4-4/waechtersauer/waechtersauer-1861.jsonl.bz2 here: langident/langident_v1-4-4/BNL/waechtersauer/waechtersauer-1861.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=waechtersauer
#     file key: will copy langident/langident_v1-4-4/waechtersauer/waechtersauer-1862.jsonl.bz2 here: langident/langident_v1-4-4/BNL/waechtersauer/waechtersauer-1862.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=waechtersauer
#     file key: will copy langident/langident_v1-4-4/waechtersauer/waechtersauer-1863.jsonl.bz2 here: langident/langident_v1-4-4/BNL/waechtersauer/waechtersauer-1863.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=waechtersauer
#     file key: will copy langident/langident_v1-4-4/waechtersauer/waechtersauer-1864.jsonl.bz2 here: langident/langident_v1-4-4/BNL/waechtersauer/waechtersauer-1864.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=waechtersauer
#     file key: will copy langident/langident_v1-4-4/waechtersauer/waechtersauer-1865.jsonl.bz2 here: langident/langident_v1-4-4/BNL/waechtersauer/waechtersauer-1865.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=waechtersauer
#     file key: will copy langident/langident_v1-4-4/waechtersauer/waechtersauer-1866.jsonl.bz2 here: langident/langident_v1-4-4/BNL/waechtersauer/waechtersauer-1866.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=waechtersauer
#     file key: will copy langident/langident_v1-4-4/waechtersauer/waechtersauer-1867.jsonl.bz2 here: langident/langident_v1-4-4/BNL/waechtersauer/waechtersauer-1867.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=waechtersauer
#     file key: will copy langident/langident_v1-4-4/waechtersauer/waechtersauer-1869.jsonl.bz2 here: langident/langident_v1-4-4/BNL/waechtersauer/waechtersauer-1869.jsonl.bz2
# media_alias: langident/langident_v1-4-4/waeschfra/
# Now processing alias waeschfra - provider = BNL
# og_partition : langident/langident_v1-4-4, current_alias=waeschfra
#     file key: will copy langident/langident_v1-4-4/waeschfra/waeschfra-1868.jsonl.bz2 here: langident/langident_v1-4-4/BNL/waeschfra/waeschfra-1868.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=waeschfra
#     file key: will copy langident/langident_v1-4-4/waeschfra/waeschfra-1869.jsonl.bz2 here: langident/langident_v1-4-4/BNL/waeschfra/waeschfra-1869.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=waeschfra
#     file key: will copy langident/langident_v1-4-4/waeschfra/waeschfra-1870.jsonl.bz2 here: langident/langident_v1-4-4/BNL/waeschfra/waeschfra-1870.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=waeschfra
#     file key: will copy langident/langident_v1-4-4/waeschfra/waeschfra-1871.jsonl.bz2 here: langident/langident_v1-4-4/BNL/waeschfra/waeschfra-1871.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=waeschfra
#     file key: will copy langident/langident_v1-4-4/waeschfra/waeschfra-1872.jsonl.bz2 here: langident/langident_v1-4-4/BNL/waeschfra/waeschfra-1872.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=waeschfra
#     file key: will copy langident/langident_v1-4-4/waeschfra/waeschfra-1873.jsonl.bz2 here: langident/langident_v1-4-4/BNL/waeschfra/waeschfra-1873.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=waeschfra
#     file key: will copy langident/langident_v1-4-4/waeschfra/waeschfra-1874.jsonl.bz2 here: langident/langident_v1-4-4/BNL/waeschfra/waeschfra-1874.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=waeschfra
#     file key: will copy langident/langident_v1-4-4/waeschfra/waeschfra-1875.jsonl.bz2 here: langident/langident_v1-4-4/BNL/waeschfra/waeschfra-1875.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=waeschfra
#     file key: will copy langident/langident_v1-4-4/waeschfra/waeschfra-1876.jsonl.bz2 here: langident/langident_v1-4-4/BNL/waeschfra/waeschfra-1876.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=waeschfra
#     file key: will copy langident/langident_v1-4-4/waeschfra/waeschfra-1877.jsonl.bz2 here: langident/langident_v1-4-4/BNL/waeschfra/waeschfra-1877.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=waeschfra
#     file key: will copy langident/langident_v1-4-4/waeschfra/waeschfra-1878.jsonl.bz2 here: langident/langident_v1-4-4/BNL/waeschfra/waeschfra-1878.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=waeschfra
#     file key: will copy langident/langident_v1-4-4/waeschfra/waeschfra-1879.jsonl.bz2 here: langident/langident_v1-4-4/BNL/waeschfra/waeschfra-1879.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=waeschfra
#     file key: will copy langident/langident_v1-4-4/waeschfra/waeschfra-1880.jsonl.bz2 here: langident/langident_v1-4-4/BNL/waeschfra/waeschfra-1880.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=waeschfra
#     file key: will copy langident/langident_v1-4-4/waeschfra/waeschfra-1881.jsonl.bz2 here: langident/langident_v1-4-4/BNL/waeschfra/waeschfra-1881.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=waeschfra
#     file key: will copy langident/langident_v1-4-4/waeschfra/waeschfra-1882.jsonl.bz2 here: langident/langident_v1-4-4/BNL/waeschfra/waeschfra-1882.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=waeschfra
#     file key: will copy langident/langident_v1-4-4/waeschfra/waeschfra-1883.jsonl.bz2 here: langident/langident_v1-4-4/BNL/waeschfra/waeschfra-1883.jsonl.bz2
# og_partition : langident/langident_v1-4-4, current_alias=waeschfra
#     file key: will copy langident/langident_v1-4-4/waeschfra/waeschfra-1884.jsonl.bz2 here: langident/langident_v1-4-4/BNL/waeschfra/waeschfra-1884.jsonl.bz2
#     -> another file: langident/langident_v1-4-4__AGGREGATED.jsonl.gz

# %%
def copy_with_provider(s3, source_key, partition, dest_bucket):

    
    dest_key = construct_dest_key(source_key, partition, src_bucket, dest_bucket)

    if
